# %%
import pandas as pd
import numpy as np
data = {"Name": ["A", "B", "C", "D", "E"],"Age": [20, np.nan, 22, np.nan, 25],"Marks": [80, 75, np.nan, 90, np.nan]}
df = pd.DataFrame(data)
print(df)
print(df.isnull())
print(df.isnull().sum())
df["Age"] = df["Age"].fillna(df["Age"].mean())
df["Marks"] = df["Marks"].fillna(df["Marks"].mean())
print(df)
df_cleaned = df.dropna()
print(df_cleaned)
df["Name"] = df["Name"].replace("A", "Student_A")
print(df)
print(df.notnull())
# Out:
#   Name   Age  Marks
# 0    A  20.0   80.0
# 1    B   NaN   75.0
# 2    C  22.0    NaN
# 3    D   NaN   90.0
# 4    E  25.0    NaN
#     Name    Age  Marks
# 0  False  False  False
# 1  False   True  False
# 2  False  False   True
# 3  False   True  False
# 4  False  False   True
# Name     0
# Age      2
# Marks    2
# dtype: int64
#   Name        Age      Marks
# 0    A  20.000000  80.000000
# 1    B  22.333333  75.000000
# 2    C  22.000000  81.666667
# 3    D  22.333333  90.000000
# 4    E  25.000000  81.666667
#   Name        Age      Marks
# 0    A  20.000000  80.000000
# 1    B  22.333333  75.000000
# 2    C  22.000000  81.666667
# 3    D  22.333333  90.000000
# 4    E  25.000000  81.666667
#         Name        Age      Marks
# 0  Student_A  20.000000  80.000000
# 1          B  22.333333  75.000000
# 2          C  22.000000  81.666667
# 3          D  22.333333  90.000000
# 4          E  25.000000  81.666667
#    Name   Age  Marks
# 0  True  True   True
# 1  True  True   True
# 2  True  True   True
# 3  True  True   True
# 4  True  True   True

# %%
import numpy as np
a=np.array([1,2,3,4,5,6])
print(a)
print(a)
# Out:
# [1 2 3 4 5 6]
# [1 2 3 4 5 6]

# %%
import matplotlib.pyplot as plt
days = [1, 2, 3, 4]
sales = [100, 150, 200, 250]
plt.plot(days, sales)
plt.title("Sales Growth")
plt.xlabel("Days")
plt.ylabel("Sales")
plt.show()

# %%
import matplotlib.pyplot as plt
c=['A','B','C','D','E']
v=[10,20,30,40,50]
plt.bar(c,v)
plt.title("Bar chart")
plt.xlabel('Categories')
plt.ylabel('Values')
plt.show()

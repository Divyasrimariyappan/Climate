# %%
import pandas as pd
data = pd.read_csv("mark.csv")
print("Dataset:\n", data)
average = data["Total"].mean()
print("Average Marks:", average)
# Out:
# Dataset:
#    Name  Age  Mark1  Mark2  Mark3  Total
# 0  XXX   15     65     67     88    220
# 1  yyy   15     88     98     79    265
# 2  zzz   15     89     80     77    246
# 3  aaa   15     78     63     81    222
# 4  bbb   15     67     88     59    214
# 5  ccc   15     64     72     77    213
# Average Marks: 230.0
